# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import jupytools.syspath
jupytools.syspath.add('..')

# %%
import json
import catboost as cb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dataset import load, n_unique, missing_info, existing_info, Subset
from style import make_colors, create_axes_if_needed, tableau, NotebookStyle
from utils import parallel

# %%
trn_data, trn_target, trn_specs = load(Subset.Train)
# Out:
# (11341042, 11) (17690, 7) (386, 3)

# %%
trn_data.sample(5)
# Out:
#          event_id      game_session                 timestamp  \
# 6469561  1bb5fbdb  e5c0db0eeafc9d1f  2019-09-10T14:51:02.128Z
# 4436131  76babcde  880969db92dfe98a  2019-08-02T16:22:15.122Z
# 8821615  f71c4741  565a615a4b5c325a  2019-09-14T02:04:44.750Z
# 1745398  5e3ea25a  0d2fe8bd363a8a6f  2019-08-01T19:54:42.598Z
# 4857912  0a08139c  1eb28bfc1a0bfb06  2019-09-17T02:52:40.532Z
#
#                                                 event_data installation_id  \
# 6469561  {"description":"Great job! You did it!","ident...        8ffeffb1
# 4436131  {"coordinates":{"x":267,"y":170,"stage_width":...        6231f60c
# 8821615  {"description":"Which tub is the right size fo...        c795f94d
# 1745398  {"coordinates":{"x":921,"y":439,"stage_width":...        281f09d5
# 4857912  {"description":"This bug is so tiny!","identif...        6cb38ea0
#
#          event_count  event_code  game_time                          title  \
# 6469561           55        3110      40621  Sandcastle Builder (Activity)
# 4436131           33        4070      64311                      Dino Dive
# 8821615           94        3010     119041                    Scrub-A-Dub
# 1745398            6        4070      14541                  Crystals Rule
# 4857912          111        3010      84681        Bug Measurer (Activity)
#
#              type        world
# 6469561  Activity    MAGMAPEAK
# 4436131      Game    MAGMAPEAK
# 8821615      Game    MAGMAPEAK
# 1745398      Game  TREETOPCITY
# 4857912  Activity  TREETOPCITY

# %%
trn_target.sample(5)
# Out:
#            game_session installation_id                         title  \
# 16771  e865f94eae139622        f1c21eda    Bird Measurer (Assessment)
# 16974  1cd93a676ff3f27f        f4fcab26  Cauldron Filler (Assessment)
# 9566   ab5400a4e11d843c        858ace47  Mushroom Sorter (Assessment)
# 9196   f5ac8a88ab9b3057        8015e006  Cauldron Filler (Assessment)
# 1723   f17b9cd839f7f55a        16276a94  Mushroom Sorter (Assessment)
#
#        num_correct  num_incorrect  accuracy  accuracy_group
# 16771            0             14      0.00               0
# 16974            1              3      0.25               1
# 9566             1              0      1.00               3
# 9196             1              0      1.00               3
# 1723             1              0      1.00               3

# %%
trn_specs.sample(5)
# Out:
#      event_id                                               info  \
# 44   53c6e11a  The beat round event is triggered when the pla...
# 75   08fd73f3  The beat round event is triggered when the pla...
# 19   3afde5dd  The system-initiated feedback (Correct) event ...
# 239  e4d32835  This event occurs when the player hovers the m...
# 264  dcb55a27  This event is triggered when the player clicks...
#
#                                                   args
# 44   [{"name":"game_time","type":"int","info":"mill...
# 75   [{"name":"game_time","type":"int","info":"mill...
# 19   [{"name":"game_time","type":"int","info":"mill...
# 239  [{"name":"game_time","type":"int","info":"mill...
# 264  [{"name":"game_time","type":"int","info":"mill...

# %%
class EventParser:
    def __init__(self, keys):
        self.keys = keys
    def __call__(self, json_str):
        obj = json.loads(json_str)
        obj = pd.io.json.json_normalize(obj)
        obj = obj.T[0].to_dict()
        row = {k: obj.get(k) for k in self.keys}
        return row

# %%
def fillna(df, column, method='mean', value=None):
    if method == 'mean':
        value = df[column].mean()
    elif method == 'mode':
        value = df[column].value_counts().index[0]
    elif method == 'const':
        assert value is not None
    else:
        raise RuntimeError(f'invalid imputing method: {method}')
    df[column] = df[column].fillna(value)
    return df

# %%
def extract_event_features(df, num_workers=12):
    parse_row = EventParser([
        'game_time', 'coordinates.y', 'coordinates.stage_height',
        'coordinates.stage_width', 'coordinates.x',
        'description', 'media_type', 'identifier',
        'duration', 'total_duration'])
    df = pd.DataFrame(parallel(parse_row, df.event_data, num_workers))
    df = fillna(df, 'game_time', method='mean')
    df = fillna(df, 'coordinates.x', method='mode')
    df = fillna(df, 'coordinates.y', method='mode')
    df = fillna(df, 'coordinates.stage_height', method='mode')
    df = fillna(df, 'coordinates.stage_width', method='mode')
    df = fillna(df, 'description', method='mode')
    df = fillna(df, 'media_type', method='const', value='none')
    df = fillna(df, 'identifier', method='const', value='none')
    df = fillna(df, 'duration', method='mean')
    df = fillna(df, 'total_duration', method='mean')
    return df

# %%
trn_event = extract_event_features(trn_data)
# Out:
# HBox(children=(IntProgress(value=0, max=11341042), HTML(value='')))

# %%
trn_event.to_feather('trn_event.feather')

# %%
dataset = pd.concat([trn_data.drop(columns='event_data'), trn_event], axis=1)

# %%
dataset
# Out:
#           event_id      game_session                 timestamp  \
# 0         27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1         27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2         77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3         b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4         1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# ...            ...               ...                       ...
# 11341037  ab3136ba  c09b94eebfdf50a6  2019-10-10T15:11:15.584Z
# 11341038  27253bdc  6ad8ab25003ef1b0  2019-10-10T15:12:17.364Z
# 11341039  27253bdc  71904dca23b982c6  2019-10-10T15:13:04.713Z
# 11341040  27253bdc  2267b18f069e875a  2019-10-10T15:13:54.545Z
# 11341041  27253bdc  f31950f549d7c242  2019-10-10T15:15:12.483Z
#
#          installation_id  event_count  event_code  game_time  \
# 0               0001e90f            1        2000          0
# 1               0001e90f            1        2000          0
# 2               0001e90f            1        2000          0
# 3               0001e90f            2        3010         53
# 4               0001e90f            3        3110       6972
# ...                  ...          ...         ...        ...
# 11341037        fffc0583           66        3110     118615
# 11341038        fffc0583            1        2000          0
# 11341039        fffc0583            1        2000          0
# 11341040        fffc0583            1        2000          0
# 11341041        fffc0583            1        2000          0
#
#                                   title      type         world  \
# 0               Welcome to Lost Lagoon!      Clip          NONE
# 1                  Magma Peak - Level 1      Clip     MAGMAPEAK
# 2         Sandcastle Builder (Activity)  Activity     MAGMAPEAK
# 3         Sandcastle Builder (Activity)  Activity     MAGMAPEAK
# 4         Sandcastle Builder (Activity)  Activity     MAGMAPEAK
# ...                                 ...       ...           ...
# 11341037                      Dino Dive      Game     MAGMAPEAK
# 11341038        Crystal Caves - Level 2      Clip  CRYSTALCAVES
# 11341039        Crystal Caves - Level 3      Clip  CRYSTALCAVES
# 11341040        Crystal Caves - Level 3      Clip  CRYSTALCAVES
# 11341041        Tree Top City - Level 2      Clip   TREETOPCITY
#
#               game_time  coordinates.y  coordinates.stage_height  \
# 0         200876.905661          207.0                     762.0
# 1         200876.905661          207.0                     762.0
# 2              0.000000          207.0                     762.0
# 3             53.000000          207.0                     762.0
# 4           6972.000000          207.0                     762.0
# ...                 ...            ...                       ...
# 11341037  118615.000000          207.0                     762.0
# 11341038  200876.905661          207.0                     762.0
# 11341039  200876.905661          207.0                     762.0
# 11341040  200876.905661          207.0                     762.0
# 11341041  200876.905661          207.0                     762.0
#
#           coordinates.stage_width  coordinates.x  \
# 0                          1015.0          782.0
# 1                          1015.0          782.0
# 2                          1015.0          782.0
# 3                          1015.0          782.0
# 4                          1015.0          782.0
# ...                           ...            ...
# 11341037                   1015.0          782.0
# 11341038                   1015.0          782.0
# 11341039                   1015.0          782.0
# 11341040                   1015.0          782.0
# 11341041                   1015.0          782.0
#
#                                                 description media_type  \
# 0         That's not enough food. Try putting a piece on...       none
# 1         That's not enough food. Try putting a piece on...       none
# 2         That's not enough food. Try putting a piece on...       none
# 3         Let's build a sandcastle! First, fill up your ...      audio
# 4         Let's build a sandcastle! First, fill up your ...      audio
# ...                                                     ...        ...
# 11341037                              Tap another dinosaur.  animation
# 11341038  That's not enough food. Try putting a piece on...       none
# 11341039  That's not enough food. Try putting a piece on...       none
# 11341040  That's not enough food. Try putting a piece on...       none
# 11341041  That's not enough food. Try putting a piece on...       none
#
#                                              identifier      duration  \
# 0                                                  none  33962.599642
# 1                                                  none  33962.599642
# 2                                                  none  33962.599642
# 3         Dot_LetsSandcastle,Dot_FillMold,Dot_MoldShape  33962.599642
# 4         Dot_LetsSandcastle,Dot_FillMold,Dot_MoldShape   6919.000000
# ...                                                 ...           ...
# 11341037                                 clip_307_touch   1450.000000
# 11341038                                           none  33962.599642
# 11341039                                           none  33962.599642
# 11341040                                           none  33962.599642
# 11341041                                           none  33962.599642
#
#           total_duration
# 0             3843.75213
# 1             3843.75213
# 2             3843.75213
# 3             6758.00000
# 4             3843.75213
# ...                  ...
# 11341037      3843.75213
# 11341038      3843.75213
# 11341039      3843.75213
# 11341040      3843.75213
# 11341041      3843.75213
#
# [11341042 rows x 20 columns]

# %%
is_assessment = dataset.title.str.contains('\(Assessment\)')

# %%
from collections import OrderedDict
sessions = OrderedDict()
for k, g in dataset.query('installation_id == "0006a69f"').groupby('game_session'):
    session_titles = g.title.unique().tolist()
    sessions[k] = session_titles

# %%
trn_target
# Out:
#            game_session installation_id                         title  \
# 0      6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1      77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2      901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3      9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4      a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# ...                 ...             ...                           ...
# 17685  c996482b11d149dd        ffc90c32    Bird Measurer (Assessment)
# 17686  b05a02b52d5c1f4c        ffd2871d  Cauldron Filler (Assessment)
# 17687  5448d652309a6324        ffeb0b1b  Cauldron Filler (Assessment)
# 17688  a6885ab824fbc32c        ffeb0b1b  Mushroom Sorter (Assessment)
# 17689  dadd1a4d8ac68ab0        ffeb0b1b  Cauldron Filler (Assessment)
#
#        num_correct  num_incorrect  accuracy  accuracy_group
# 0                1              0  1.000000               3
# 1                0             11  0.000000               0
# 2                1              0  1.000000               3
# 3                1              1  0.500000               2
# 4                1              0  1.000000               3
# ...            ...            ...       ...             ...
# 17685            1              0  1.000000               3
# 17686            1              0  1.000000               3
# 17687            1              2  0.333333               1
# 17688            0              1  0.000000               0
# 17689            1              2  0.333333               1
#
# [17690 rows x 7 columns]

# %%
[tst_data] = load(Subset.Test)
# Out:
# (1156414, 11)

# %%
tst_data
# Out:
#          event_id      game_session                 timestamp  \
# 0        27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1        27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2        27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3        27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4        7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
# ...           ...               ...                       ...
# 1156409  c74f40cd  46ff9d3ad2be09f2  2019-09-28T21:20:40.918Z
# 1156410  6c930e6e  46ff9d3ad2be09f2  2019-09-28T21:20:41.493Z
# 1156411  a5be6304  46ff9d3ad2be09f2  2019-09-28T21:20:45.499Z
# 1156412  27253bdc  96d7dc31e822cedc  2019-09-28T21:21:05.670Z
# 1156413  f56e0afc  6897df1e7b5ccdf7  2019-09-28T21:21:56.105Z
#
#                                                 event_data installation_id  \
# 0                   {"event_code": 2000, "event_count": 1}        00abaee7
# 1                   {"event_code": 2000, "event_count": 1}        00abaee7
# 2                   {"event_code": 2000, "event_count": 1}        00abaee7
# 3                   {"event_code": 2000, "event_count": 1}        00abaee7
# 4        {"version":"1.0","round":0,"event_count":1,"ga...        00abaee7
# ...                                                    ...             ...
# 1156409  {"description":"Alright! This one is the littl...        ffe774cc
# 1156410  {"duration":20008,"misses":0,"event_count":40,...        ffe774cc
# 1156411  {"session_duration":36607,"exit_type":"game_co...        ffe774cc
# 1156412             {"event_code": 2000, "event_count": 1}        ffe774cc
# 1156413  {"version":"1.0","event_count":1,"game_time":0...        ffe774cc
#
#          event_count  event_code  game_time                         title  \
# 0                  1        2000          0       Welcome to Lost Lagoon!
# 1                  1        2000          0          Magma Peak - Level 1
# 2                  1        2000          0          Magma Peak - Level 2
# 3                  1        2000          0       Crystal Caves - Level 1
# 4                  1        2000          0                     Chow Time
# ...              ...         ...        ...                           ...
# 1156409           39        3121      32030  Mushroom Sorter (Assessment)
# 1156410           40        2030      32584  Mushroom Sorter (Assessment)
# 1156411           41        2010      36607  Mushroom Sorter (Assessment)
# 1156412            1        2000          0       Tree Top City - Level 3
# 1156413            1        2000          0    Bird Measurer (Assessment)
#
#                type         world
# 0              Clip          NONE
# 1              Clip     MAGMAPEAK
# 2              Clip     MAGMAPEAK
# 3              Clip  CRYSTALCAVES
# 4              Game  CRYSTALCAVES
# ...             ...           ...
# 1156409  Assessment   TREETOPCITY
# 1156410  Assessment   TREETOPCITY
# 1156411  Assessment   TREETOPCITY
# 1156412        Clip   TREETOPCITY
# 1156413  Assessment   TREETOPCITY
#
# [1156414 rows x 11 columns]
