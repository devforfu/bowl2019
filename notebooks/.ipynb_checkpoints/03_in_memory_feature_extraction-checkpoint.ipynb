# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import jupytools.syspath
jupytools.syspath.add('..')

# %%
import feather
import pandas as pd
from basedir import TRAIN, TEST
from dataset import load, load_sample, Subset
from extract_features import prepare, BaselineWithTimestampFeatures

# %%
trn_data, trn_targ, trn_spec = load(Subset.Train)
# Out:
# (11341042, 11) (17690, 7) (386, 3)

# %%
trn_data = prepare(trn_data, BaselineWithTimestampFeatures(), 
                   targets=trn_targ, pbar=True, dedup=True,
                   num_workers=12)
# Out:
# HBox(children=(IntProgress(value=0, description='Processing events', max=11341042, style=ProgressStyle(descrip…

# %%
trn_data.to_feather('X_trn.feather')

# %%
tst_data = prepare(tst_data, BaselineWithTimestampFeatures(), pbar=True, dedup=True, num_workers=12)

# %%
tst_data.to_feather('X_tst.feather')

# %%
trn_targ[['accuracy_group']].to_feather('y.feather')

# %%
X_trn = feather.read_dataframe('X_trn.feather')

# %%
X_trn
# Out:
#            game_session installation_id  events_count  game_session_uniq  \
# 0      901acc108f55a5a1        0006a69f           695                 19
# 1      77b8ee947eb84b4e        0006a69f          1230                 26
# 2      6bdf9623adc94d89        0006a69f          1265                 27
# 3      9501794defd84e4d        0006a69f          2201                 48
# 4      a9ef3ecb3d1acc6a        0006a69f          2618                 57
# ...                 ...             ...           ...                ...
# 17685  460e8bdc2822b340        ffc90c32          2001                 50
# 17686  b05a02b52d5c1f4c        ffd2871d           928                  9
# 17687  dadd1a4d8ac68ab0        ffeb0b1b          1021                 19
# 17688  a6885ab824fbc32c        ffeb0b1b          1455                 34
# 17689  5448d652309a6324        ffeb0b1b          1593                 37
#
#        title_uniq  event_count_max  event_code_least  event_code_most  \
# 0              15              166              4100             4030
# 1              22              204              2060             3010
# 2              22              204              2060             3010
# 3              27              215              4095             4070
# 4              27              215              4095             3010
# ...           ...              ...               ...              ...
# 17685          43              249              4110             4070
# 17686           9              303              4100             4070
# 17687           8              604              2010             4030
# 17688           9              604              2025             4030
# 17689           9              604              2025             4030
#
#        event_code_uniq  game_time_min  ...  world_crystalcaves_freq  \
# 0                   28              0  ...                 0.000000
# 1                   31              0  ...                 0.000000
# 2                   31              0  ...                 0.000000
# 3                   37              0  ...                 0.000000
# 4                   38              0  ...                 0.000000
# ...                ...            ...  ...                      ...
# 17685               39              0  ...                 0.244378
# 17686               31              0  ...                 0.000000
# 17687               20              0  ...                 0.604310
# 17688               22              0  ...                 0.648797
# 17689               22              0  ...                 0.592593
#
#        media_uniq  media_least  media_most  media_none_count  \
# 0               3        audio        none               491
# 1               3        audio        none               701
# 2               3        audio        none               722
# 3               3        audio        none              1378
# 4               3        audio        none              1522
# ...           ...          ...         ...               ...
# 17685           3        audio        none              1300
# 17686           3        audio        none               651
# 17687           3        audio        none               556
# 17688           3        audio        none               818
# 17689           3        audio        none               890
#
#        media_audio_count media_animation_count media_none_freq  \
# 0                     89                   115        0.706475
# 1                    115                   414        0.569919
# 2                    129                   414        0.570751
# 3                    309                   514        0.626079
# 4                    319                   777        0.581360
# ...                  ...                   ...             ...
# 17685                228                   473        0.649675
# 17686                109                   168        0.701509
# 17687                182                   283        0.544564
# 17688                198                   439        0.562199
# 17689                264                   439        0.558694
#
#        media_audio_freq  media_animation_freq
# 0              0.128058              0.165468
# 1              0.093496              0.336585
# 2              0.101976              0.327273
# 3              0.140391              0.233530
# 4              0.121849              0.296791
# ...                 ...                   ...
# 17685          0.113943              0.236382
# 17686          0.117457              0.181034
# 17687          0.178257              0.277179
# 17688          0.136082              0.301718
# 17689          0.165725              0.275581
#
# [17690 rows x 46 columns]
