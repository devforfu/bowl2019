# %%
# !cp /kaggle/input/data-bowl-2019-external-data/*.py /kaggle/working

# %%
# %reload_ext autoreload
# %autoreload 2
import warnings
import jupytools.syspath
def ignore(*args, **kwargs): pass
warnings.warn = ignore
jupytools.syspath.add('..')

# %%
from collections import Counter, OrderedDict
from functools import partial

import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.metrics import cohen_kappa_score
from sklearn.model_selection import GroupKFold
from tqdm.auto import tqdm

import bundle
import features as F
import selection
import utils as U
from dataset import load, load_sample, Subset
from encode import encode
from training import train, inference, submit, EnsembleTrainer, get_default_config
from meta import compute_meta_data
from metric import optimize_rounding_bounds, make_cappa_metric
from normalize import normalize

# %%
sample = False
if U.on_kaggle():
    U.log('Loading test set only.')
    tst_data = pd.read_csv('/kaggle/input/data-science-bowl-2019/test.csv')
else:
    if sample:
        U.log('Warning: loading train and test data sample.')
        trn_data, _, _ = load_sample(Subset.Train, 500_000)
        [tst_data] = load_sample(Subset.Test, 500_000)
    else:
        U.log('Loading train and test.')
        trn_data, trn_spec, trn_targ = load(Subset.Train)
        [tst_data] = load(Subset.Test)
# Out:
# Loading train and test.
# (11341042, 11) (17690, 7) (386, 3) (1156414, 11)

# %%
transform = U.combine(
    partial(F.add_feature_combinations, pairs=[('title', 'event_code'),
                                               ('title', 'world'),
                                               ('title', 'type'),
                                               ('world', 'type')]),
    partial(F.add_datetime, column='timestamp', prefix='ts'),
)

if U.on_kaggle():
    U.log('Transforming test data only.')
    X_tst = transform(tst_data.copy())
    U.log(X_tst.shape)
else:
    U.log('Transforming train and test data.')
    X_tst = transform(tst_data.copy())
    X_trn = transform(trn_data.copy())
    U.log(X_trn.shape, X_tst.shape)
# Out:
# Transforming train and test data.
# (11341042, 22) (1156414, 22)

# %%
if U.on_kaggle():
    U.log('Reading pre-computed meta from disk.')
    meta = bundle.meta()
else:
    U.log('Computing meta using train and test datasets.')
    meta = compute_meta_data(X_trn, X_tst)
    U.log('Saving computed meta on disk.')
    bundle.save_meta(meta, 'meta')
# Out:
# Computing meta using train and test datasets.
# Saving computed meta on disk.

# %%
extractor = F.FeaturesExtractor([
    F.CountingFeatures(meta),
    F.PerformanceFeatures(meta),
    F.VarietyFeatures(meta),
    F.EventDataFeatures(meta),
    F.FeedbackFeatures(meta),
    F.TimestampFeatures2(meta),
    # F.ZFeatures(meta)
])

algo = F.InMemoryAlgorithm(extractor, meta, num_workers=12)

cat_cols = ['session_title','cnt_most_freq_title', 'cnt_least_freq_title', 
            'cnt_most_freq_world', 'cnt_least_freq_world', 'cnt_most_freq_type', 
            'cnt_least_freq_type', 'cnt_most_freq_title_world', 
            'cnt_least_freq_title_world', 'cnt_most_freq_title_type', 
            'cnt_least_freq_title_type', 'cnt_most_freq_world_type', 
            'cnt_least_freq_world_type']

if U.on_kaggle():
    U.log('Preparing test dataset.')
    X_tst = algo.run(X_tst, test=True)
    encoders = bundle.encoders()
    X_tst, _ = encode(X_tst, cat_cols, encoders=encoders)
else:
    U.log('Preparing train and test datasets.')
    X_trn = algo.run(X_trn)
    X_tst = algo.run(X_tst, test=True)
    X_trn, encoders = encode(X_trn, cat_cols)
    X_tst, _ = encode(X_tst, cat_cols, encoders=encoders)
    bundle.save(encoders, 'encoders')
# Out:
# Preparing train and test datasets.
# Running algorithm in train mode.
# HBox(children=(FloatProgress(value=0.0, max=17000.0), HTML(value='')))
# Running algorithm in test mode.
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
if U.on_kaggle():
    U.log('Running post-processing on test set only.')
    F.add_user_wise_features(X_tst, meta)
else:
    U.log('Running post-processing on train and test sets.')
    F.add_user_wise_features(X_trn, meta)
    F.add_user_wise_features(X_tst, meta)
# Out:
# Running post-processing on train and test sets.

# %%
te_features = list(np.unique(cat_cols + U.starts_with(X_trn.columns, 'cnt_')))

# %%
def encode_multi_target(dataset, feature, target='accuracy_group', smoothing=3.0):
    from category_encoders import TargetEncoder
    mappings = []
    for i in (1, 2, 3):
        target_col = dataset[target].map(lambda x: int(x == i))
        te = TargetEncoder(cols=[feature], smoothing=smoothing)
        te.fit(dataset, target_col)
        mapping = te.mapping[feature]
        mapping = {k-1: v for k, v in mapping.to_dict().items() if k > 0}
        dataset[f'te_{feature}_{i}'] = dataset[feature].map(mapping)
        mappings.append(mapping)
    return feature, mappings

if U.on_kaggle():
    te = bundle.target_encoders()
    for feature, mappings in te.items():
        for i, mapping in enumerate(mappings, 1):
            X_tst[f'te_{feature}_{i}'] = X_tst[feature].map(mapping)
else:
    target_encoders = {}
    for feature in tqdm(te_features, desc='Target Encoder'):
        feature, mappings = encode_multi_target(X_trn, feature=feature)
        target_encoders[feature] = mappings
    for feature, mappings in target_encoders.items():
        for i, mapping in enumerate(mappings, 1):
            X_tst[f'te_{feature}_{i}'] = X_tst[feature].map(mapping)
    bundle.save(target_encoders, 'target_encoders')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Target Encoder', max=995.0, style=ProgressStyle(descripti…

# %%
for feature, mappings in target_encoders.items():
    for i, mapping in enumerate(mappings, 1):
        X_trn[f'te_{feature}_{i}'] = X_trn[feature].map(mapping)

# %%
# if not U.on_kaggle():
#     with pd.option_context('display.max_rows', 2000):
#         display(X_trn.sample(3).T)

# %%
if not U.on_kaggle():
    X_trn.to_pickle('/tmp/X_trn.pickle')
    X_tst.to_pickle('/tmp/X_tst.pickle')

# %%
if not U.on_kaggle():
    X_trn = pd.read_pickle('/tmp/X_trn.pickle')
    X_tst = pd.read_pickle('/tmp/X_tst.pickle')

# %%
# group_col = 'installation_id'
# U.log(f'Normalizing dataset using column for grouping: {group_col}')
# norm_dataset = X_tst if U.on_kaggle() else X_trn
# cnt_cols = U.starts_with(norm_dataset.columns, 'cnt_')
# normalize(norm_dataset, cnt_cols, grouping_key=group_col, method='min-max')

# %% [markdown]
# ## Features Selection

# %%
selector = selection.FeatureSelection(
    rules=[
        ('nonzero', selection.non_zero_rows_and_cols),
    ],
    ignore_cols=[
        'accuracy_group', 
        'installation_id', 
        'game_session'
    ]
)
if U.on_kaggle():
    U.log('Loading relevant features list from disk.')
    features = bundle.features()
else:
    U.log('Deriving relevant features from train dataset.')
    features = selector.select(X_trn)
    bundle.save(features, 'features')
# Out:
# Deriving relevant features from train dataset.
# Excluding from consideration: ['accuracy_group', 'installation_id', 'game_session']
# Applying feature selection rule: nonzero
# Selected features: 4091 of 4127
# Keeping only features, selected by every rule.
# Final number of features changed from 4127 to 4091

# %% [markdown]
# ## Submission

# %%
bundle.save({
    'rounders': rounders, 
    'ensemble': [result.models for result in ensemble]
}, key='lightgbm')

# %%
bundle.package(folder='/home/ck/data/bowl2019/external/')
# Out:
# Packaging training results into dataset.
# /tmp/bowl2019/meta.joblib --> /home/ck/data/bowl2019/external/meta.joblib
# /tmp/bowl2019/lightgbm.joblib --> /home/ck/data/bowl2019/external/lightgbm.joblib
# /tmp/bowl2019/target_encoders.joblib --> /home/ck/data/bowl2019/external/target_encoders.joblib
# /tmp/bowl2019/bounds.joblib --> /home/ck/data/bowl2019/external/bounds.joblib
# /tmp/bowl2019/features.joblib --> /home/ck/data/bowl2019/external/features.joblib
# /tmp/bowl2019/encoders.joblib --> /home/ck/data/bowl2019/external/encoders.joblib
# /tmp/bowl2019/models_lightgbm_24.joblib --> /home/ck/data/bowl2019/external/models_lightgbm_24.joblib
# /tmp/bowl2019/models_lightgbm_023.joblib --> /home/ck/data/bowl2019/external/models_lightgbm_023.joblib
# Packaging helper scripts into dataset.
# ../selection.py --> /home/ck/data/bowl2019/external/selection.py
# ../encode.py --> /home/ck/data/bowl2019/external/encode.py
# ../features.py --> /home/ck/data/bowl2019/external/features.py
# ../training.py --> /home/ck/data/bowl2019/external/training.py
# ../feedback.py --> /home/ck/data/bowl2019/external/feedback.py
# ../style.py --> /home/ck/data/bowl2019/external/style.py
# ../duration.py --> /home/ck/data/bowl2019/external/duration.py
# ../basedir.py --> /home/ck/data/bowl2019/external/basedir.py
# ../dataset.py --> /home/ck/data/bowl2019/external/dataset.py
# ../models.py --> /home/ck/data/bowl2019/external/models.py
# ../extract_features.py --> /home/ck/data/bowl2019/external/extract_features.py
# ../plots.py --> /home/ck/data/bowl2019/external/plots.py
# ../rounding.py --> /home/ck/data/bowl2019/external/rounding.py
# ../normalize.py --> /home/ck/data/bowl2019/external/normalize.py
# ../meta.py --> /home/ck/data/bowl2019/external/meta.py
# ../bundle.py --> /home/ck/data/bowl2019/external/bundle.py
# ../metric.py --> /home/ck/data/bowl2019/external/metric.py
# ../utils.py --> /home/ck/data/bowl2019/external/utils.py
# '/home/ck/data/bowl2019/external/'

# %%
if U.on_kaggle():
    U.log('Inference on Kaggle.')
    features = bundle.features()
    lightgbm = bundle.load('lightgbm')
    labels = []
    U.log('Running model predictions.')
    for rounder in lightgbm['rounders']:
        U.log(f'Using rounding method: {rounder.method}')
        for models in lightgbm['ensemble']:
            for model in models:
                model_pred = model.predict(X_tst[features])
                model_labels = rounder.predict(model_pred)
                labels.append(model_labels)
    labels = np.column_stack(labels)
    predictions = []
    U.log('Majority vote.')
    for label in labels:
        majority = Counter(label).most_common(1)[0][0]
        predictions.append(majority)
    U.log('Saving predictions on disk.')
    filename = submit(predictions)
    submit_df = pd.read_csv(filename)
    U.log('First 20 submission rows:')
    display(submit_df.head(20))
            
    #features = bundle.features()
    #bounds = bundle.bounds()
    #predicted = inference(X_tst, features, bounds=bounds, model=algo, version=version)
    #U.log('Saving predictions on disk.')
    #filename = submit(predicted)
    #submit_df = pd.read_csv(filename)
    #U.log('First 20 submission rows:')
    #display(submit_df.head(20))

# %%
rounders = [Rounder(method='dist'), Rounder(method='optimal')]
labels = []
for rounder in rounders:
    for i, result in enumerate(ensemble, 1):
        rounder.fit(X_trn['accuracy_group'], result.oof)
        for j, model in enumerate(result.models, 1):
            U.log(f'Rounder: {rounder.method}, ensemble #{i}, model #{j}')
            model_pred = model.predict(X_tst[features])
            model_labels = rounder.predict(model_pred)
            labels.append(model_labels)

# %%
from rounding import Rounder

# %%
def seed_all(value):
    import random
    random.seed(value)
    np.random.seed(value)

# %%
features = bundle.features()

# %%
ensemble = []
U.log('Start training an ensemble of models with various random seeds.')
trainer = EnsembleTrainer(algo='lightgbm', eval_metric='rmse')
fold = GroupKFold(n_splits=5)
for i in range(5):
    seed = np.random.randint(0, 1001)
    U.log('=' * 80)
    U.log(f'Training model with random seed: {seed}')
    seed_all(seed)
    config = get_default_config('lightgbm')
    U.set_nested(config, 'model_params.seed', seed)
    U.set_nested(config, 'model_params.feature_fraction', 0.4)
    U.set_nested(config, 'model_params.bagging_fraction', 0.6)
    U.set_nested(config, 'model_params.bagging_freq', 1)
    U.set_nested(config, 'model_params.learning_rate', 0.003)
    U.set_nested(config, 'model_params.n_estimators', 10000)
    U.set_nested(config, 'fit_params.verbose', 250)
    U.set_nested(config, 'fit_params.early_stopping_rounds', 250)
    result = trainer.train(X_trn, features=features, fold=fold, config=config)
    ensemble.append(result)
# Out:
# Start training an ensemble of models with various random seeds.
# ================================================================================
# Training model with random seed: 91
# Running k-fold 1 of 5
# Training until validation scores don't improve for 250 rounds.
# [250]	trn's rmse: 1.06746	val's rmse: 1.08523
# [500]	trn's rmse: 0.987306	val's rmse: 1.02252
# [750]	trn's rmse: 0.944411	val's rmse: 0.997515
# [1000]	trn's rmse: 0.915548	val's rmse: 0.986274
# [1250]	trn's rmse: 0.892956	val's rmse: 0.980646
# [1500]	trn's rmse: 0.873281	val's rmse: 0.977601
# [1750]	trn's rmse: 0.855888	val's rmse: 0.975981
# [2000]	trn's rmse: 0.839793	val's rmse: 0.974742

# %%
rounders = [Rounder(method='dist'), Rounder(method='optimal')]
labels = []
for rounder in rounders:
    for i, result in enumerate(ensemble, 1):
        rounder.fit(X_trn['accuracy_group'], result.oof)
        for j, model in enumerate(result.models, 1):
            U.log(f'Rounder: {rounder.method}, ensemble #{i}, model #{j}')
            model_pred = model.predict(X_tst[features])
            model_labels = rounder.predict(model_pred)
            labels.append(model_labels)

# %%
bundle.save({
    'rounders': rounders, 
    'ensemble': [result.models for result in ensemble]
}, key='lightgbm')

# %%
from multiprocessing import Queue, Process

# %%
ensemble = []
U.log('Start training an ensemble of models with various random seeds.')
trainer = EnsembleTrainer(algo='xgboost', eval_metric='rmse')
fold = GroupKFold(n_splits=5)
for i in range(5):
    seed = np.random.randint(0, 1001)
    U.log('=' * 80)
    U.log(f'Training model with random seed: {seed}')
    seed_all(seed)
    config = get_default_config('xgboost')
    U.set_nested(config, 'model_params.seed', seed)
    U.set_nested(config, 'model_params.max_depth', 6)
    U.set_nested(config, 'model_params.subsample', 0.5)
    U.set_nested(config, 'model_params.colsample_bytree', 0.8)
    U.set_nested(config, 'model_params.colsample_bylevel', 0.6)
    U.set_nested(config, 'model_params.colsample_bynode', 0.5)
    U.set_nested(config, 'model_params.learning_rate', 0.003)
    U.set_nested(config, 'model_params.n_estimators', 5000)
    U.set_nested(config, 'model_params.lambda', 1)
    U.set_nested(config, 'model_params.alpha', 1)
    U.set_nested(config, 'model_params.objective', 'reg:squarederror')
    # U.set_nested(config, 'model_params.gpu_id', 1)
    U.set_nested(config, 'model_params.nthread', 12)
    U.set_nested(config, 'model_params.tree_method', 'hist')
    U.set_nested(config, 'fit_params.verbose', 100)
    U.set_nested(config, 'fit_params.early_stopping_rounds', 100)
    result = trainer.train(X_trn, features=features, fold=fold, config=config)
    ensemble.append(result)
# Out:
# Start training an ensemble of models with various random seeds.
# ================================================================================
# Training model with random seed: 875
# Running k-fold 1 of 5
# [0]	validation_0-rmse:1.86716	validation_1-rmse:1.86478
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53987	validation_1-rmse:1.5447
# [200]	validation_0-rmse:1.3199	validation_1-rmse:1.33309
# [300]	validation_0-rmse:1.17516	validation_1-rmse:1.19777
# [400]	validation_0-rmse:1.08176	validation_1-rmse:1.1134
# [500]	validation_0-rmse:1.0218	validation_1-rmse:1.0622
# [600]	validation_0-rmse:0.982178	validation_1-rmse:1.03073
# [700]	validation_0-rmse:0.954875	validation_1-rmse:1.01114
# [800]	validation_0-rmse:0.935723	validation_1-rmse:0.999103
# [900]	validation_0-rmse:0.921191	validation_1-rmse:0.991458
# [1000]	validation_0-rmse:0.909429	validation_1-rmse:0.986045
# [1100]	validation_0-rmse:0.899873	validation_1-rmse:0.982395
# [1200]	validation_0-rmse:0.891464	validation_1-rmse:0.9799
# [1300]	validation_0-rmse:0.883882	validation_1-rmse:0.977705
# [1400]	validation_0-rmse:0.877562	validation_1-rmse:0.975995
# [1500]	validation_0-rmse:0.871608	validation_1-rmse:0.97471
# [1600]	validation_0-rmse:0.865965	validation_1-rmse:0.973794
# [1700]	validation_0-rmse:0.860441	validation_1-rmse:0.972655
# [1800]	validation_0-rmse:0.855136	validation_1-rmse:0.972097
# [1900]	validation_0-rmse:0.850133	validation_1-rmse:0.971732
# [2000]	validation_0-rmse:0.845326	validation_1-rmse:0.971082
# [2100]	validation_0-rmse:0.840516	validation_1-rmse:0.970608
# [2200]	validation_0-rmse:0.836075	validation_1-rmse:0.97001
# [2300]	validation_0-rmse:0.831563	validation_1-rmse:0.969758
# [2400]	validation_0-rmse:0.827351	validation_1-rmse:0.969668
# [2500]	validation_0-rmse:0.823031	validation_1-rmse:0.969318
# [2600]	validation_0-rmse:0.818899	validation_1-rmse:0.969027
# [2700]	validation_0-rmse:0.814813	validation_1-rmse:0.96859
# [2800]	validation_0-rmse:0.810976	validation_1-rmse:0.968492
# Stopping. Best iteration:
# [2780]	validation_0-rmse:0.811817	validation_1-rmse:0.968454
#
# Running k-fold 2 of 5
# [0]	validation_0-rmse:1.86307	validation_1-rmse:1.88091
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53717	validation_1-rmse:1.56036
# [200]	validation_0-rmse:1.31865	validation_1-rmse:1.34881
# [300]	validation_0-rmse:1.17522	validation_1-rmse:1.2134
# [400]	validation_0-rmse:1.08287	validation_1-rmse:1.12955
# [500]	validation_0-rmse:1.02286	validation_1-rmse:1.0774
# [600]	validation_0-rmse:0.983564	validation_1-rmse:1.04562
# [700]	validation_0-rmse:0.956885	validation_1-rmse:1.02638
# [800]	validation_0-rmse:0.937468	validation_1-rmse:1.01429
# [900]	validation_0-rmse:0.923025	validation_1-rmse:1.00622
# [1000]	validation_0-rmse:0.911563	validation_1-rmse:1.0008
# [1100]	validation_0-rmse:0.902413	validation_1-rmse:0.996902
# [1200]	validation_0-rmse:0.894433	validation_1-rmse:0.994173
# [1300]	validation_0-rmse:0.887148	validation_1-rmse:0.992172
# [1400]	validation_0-rmse:0.88057	validation_1-rmse:0.990591
# [1500]	validation_0-rmse:0.874382	validation_1-rmse:0.989624
# [1600]	validation_0-rmse:0.868651	validation_1-rmse:0.988513
# [1700]	validation_0-rmse:0.863102	validation_1-rmse:0.987777
# [1800]	validation_0-rmse:0.857646	validation_1-rmse:0.987065
# [1900]	validation_0-rmse:0.852866	validation_1-rmse:0.986447
# [2000]	validation_0-rmse:0.848309	validation_1-rmse:0.98605
# [2100]	validation_0-rmse:0.843947	validation_1-rmse:0.985608
# [2200]	validation_0-rmse:0.839455	validation_1-rmse:0.985244
# [2300]	validation_0-rmse:0.835307	validation_1-rmse:0.98505
# [2400]	validation_0-rmse:0.831043	validation_1-rmse:0.984917
# [2500]	validation_0-rmse:0.826805	validation_1-rmse:0.984782
# Stopping. Best iteration:
# [2486]	validation_0-rmse:0.827358	validation_1-rmse:0.984738
#
# Running k-fold 3 of 5
# [0]	validation_0-rmse:1.8598	validation_1-rmse:1.89393
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53535	validation_1-rmse:1.5679
# [200]	validation_0-rmse:1.31681	validation_1-rmse:1.35013
# [300]	validation_0-rmse:1.17457	validation_1-rmse:1.21104
# [400]	validation_0-rmse:1.08224	validation_1-rmse:1.12336
# [500]	validation_0-rmse:1.02265	validation_1-rmse:1.06932
# [600]	validation_0-rmse:0.983385	validation_1-rmse:1.03616
# [700]	validation_0-rmse:0.9568	validation_1-rmse:1.01582
# [800]	validation_0-rmse:0.937828	validation_1-rmse:1.00341
# [900]	validation_0-rmse:0.92317	validation_1-rmse:0.995554
# [1000]	validation_0-rmse:0.911697	validation_1-rmse:0.9901
# [1100]	validation_0-rmse:0.90192	validation_1-rmse:0.986703
# [1200]	validation_0-rmse:0.893404	validation_1-rmse:0.98421
# [1300]	validation_0-rmse:0.88606	validation_1-rmse:0.982322
# [1400]	validation_0-rmse:0.879403	validation_1-rmse:0.98096
# [1500]	validation_0-rmse:0.873132	validation_1-rmse:0.980082
# [1600]	validation_0-rmse:0.867642	validation_1-rmse:0.97914
# [1700]	validation_0-rmse:0.86214	validation_1-rmse:0.978738
# [1800]	validation_0-rmse:0.856803	validation_1-rmse:0.978303
# [1900]	validation_0-rmse:0.851931	validation_1-rmse:0.977941
# [2000]	validation_0-rmse:0.847339	validation_1-rmse:0.977573
# [2100]	validation_0-rmse:0.842996	validation_1-rmse:0.977407
# [2200]	validation_0-rmse:0.838409	validation_1-rmse:0.977281
# [2300]	validation_0-rmse:0.83417	validation_1-rmse:0.977162
# [2400]	validation_0-rmse:0.829854	validation_1-rmse:0.977136
# [2500]	validation_0-rmse:0.825825	validation_1-rmse:0.977046
# Stopping. Best iteration:
# [2465]	validation_0-rmse:0.827165	validation_1-rmse:0.977005
#
# Running k-fold 4 of 5
# [0]	validation_0-rmse:1.87447	validation_1-rmse:1.83517
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.54313	validation_1-rmse:1.52526
# [200]	validation_0-rmse:1.32044	validation_1-rmse:1.32323
# [300]	validation_0-rmse:1.1738	validation_1-rmse:1.19587
# [400]	validation_0-rmse:1.07939	validation_1-rmse:1.11903
# [500]	validation_0-rmse:1.01839	validation_1-rmse:1.07271
# [600]	validation_0-rmse:0.978061	validation_1-rmse:1.04506
# [700]	validation_0-rmse:0.950906	validation_1-rmse:1.02857
# [800]	validation_0-rmse:0.931267	validation_1-rmse:1.01825
# [900]	validation_0-rmse:0.916476	validation_1-rmse:1.01162
# [1000]	validation_0-rmse:0.904715	validation_1-rmse:1.00714
# [1100]	validation_0-rmse:0.894917	validation_1-rmse:1.00396
# [1200]	validation_0-rmse:0.886415	validation_1-rmse:1.0015
# [1300]	validation_0-rmse:0.878925	validation_1-rmse:0.999675
# [1400]	validation_0-rmse:0.872068	validation_1-rmse:0.998198
# [1500]	validation_0-rmse:0.866163	validation_1-rmse:0.997257
# [1600]	validation_0-rmse:0.860515	validation_1-rmse:0.996657
# [1700]	validation_0-rmse:0.855153	validation_1-rmse:0.996043
# [1800]	validation_0-rmse:0.850245	validation_1-rmse:0.995622
# [1900]	validation_0-rmse:0.844994	validation_1-rmse:0.995125
# [2000]	validation_0-rmse:0.840178	validation_1-rmse:0.994848
# [2100]	validation_0-rmse:0.835319	validation_1-rmse:0.994489
# [2200]	validation_0-rmse:0.830636	validation_1-rmse:0.994061
# [2300]	validation_0-rmse:0.826471	validation_1-rmse:0.993912
# [2400]	validation_0-rmse:0.822369	validation_1-rmse:0.993777
# [2500]	validation_0-rmse:0.818029	validation_1-rmse:0.993656
# Stopping. Best iteration:
# [2489]	validation_0-rmse:0.818524	validation_1-rmse:0.993544
#
# Running k-fold 5 of 5
# [0]	validation_0-rmse:1.86877	validation_1-rmse:1.85833
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53927	validation_1-rmse:1.54566
# [200]	validation_0-rmse:1.31708	validation_1-rmse:1.34117
# [300]	validation_0-rmse:1.17084	validation_1-rmse:1.21229
# [400]	validation_0-rmse:1.07621	validation_1-rmse:1.13368
# [500]	validation_0-rmse:1.01476	validation_1-rmse:1.08687
# [600]	validation_0-rmse:0.974354	validation_1-rmse:1.059
# [700]	validation_0-rmse:0.946975	validation_1-rmse:1.04265
# [800]	validation_0-rmse:0.92722	validation_1-rmse:1.03273
# [900]	validation_0-rmse:0.912319	validation_1-rmse:1.02636
# [1000]	validation_0-rmse:0.900447	validation_1-rmse:1.0224
# [1100]	validation_0-rmse:0.890746	validation_1-rmse:1.01983
# [1200]	validation_0-rmse:0.882211	validation_1-rmse:1.01781
# [1300]	validation_0-rmse:0.874735	validation_1-rmse:1.01604
# [1400]	validation_0-rmse:0.867582	validation_1-rmse:1.0149
# [1500]	validation_0-rmse:0.861279	validation_1-rmse:1.01391
# [1600]	validation_0-rmse:0.855259	validation_1-rmse:1.01324
# [1700]	validation_0-rmse:0.849783	validation_1-rmse:1.01267
# [1800]	validation_0-rmse:0.844541	validation_1-rmse:1.01224
# [1900]	validation_0-rmse:0.83932	validation_1-rmse:1.01183
# [2000]	validation_0-rmse:0.834461	validation_1-rmse:1.01159
# [2100]	validation_0-rmse:0.829706	validation_1-rmse:1.01123
# [2200]	validation_0-rmse:0.825177	validation_1-rmse:1.01112
# [2300]	validation_0-rmse:0.82066	validation_1-rmse:1.01095
# [2400]	validation_0-rmse:0.816556	validation_1-rmse:1.01068
# [2500]	validation_0-rmse:0.812407	validation_1-rmse:1.01056
# [2600]	validation_0-rmse:0.808212	validation_1-rmse:1.01035
# [2700]	validation_0-rmse:0.804144	validation_1-rmse:1.01031
# Stopping. Best iteration:
# [2690]	validation_0-rmse:0.804549	validation_1-rmse:1.01026
#
# ================================================================================
# Training model with random seed: 234
# Running k-fold 1 of 5
# [0]	validation_0-rmse:1.86722	validation_1-rmse:1.86478
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53942	validation_1-rmse:1.54454
# [200]	validation_0-rmse:1.31924	validation_1-rmse:1.33252
# [300]	validation_0-rmse:1.17517	validation_1-rmse:1.19744
# [400]	validation_0-rmse:1.08157	validation_1-rmse:1.11306
# [500]	validation_0-rmse:1.02131	validation_1-rmse:1.0619
# [600]	validation_0-rmse:0.981807	validation_1-rmse:1.03037
# [700]	validation_0-rmse:0.954931	validation_1-rmse:1.01098
# [800]	validation_0-rmse:0.935773	validation_1-rmse:0.998736
# [900]	validation_0-rmse:0.921315	validation_1-rmse:0.990833
# [1000]	validation_0-rmse:0.909551	validation_1-rmse:0.98577
# [1100]	validation_0-rmse:0.900195	validation_1-rmse:0.982136
# [1200]	validation_0-rmse:0.892027	validation_1-rmse:0.979414
# [1300]	validation_0-rmse:0.884749	validation_1-rmse:0.977432
# [1400]	validation_0-rmse:0.878207	validation_1-rmse:0.975778
# [1500]	validation_0-rmse:0.872013	validation_1-rmse:0.974422
# [1600]	validation_0-rmse:0.866295	validation_1-rmse:0.973242
# [1700]	validation_0-rmse:0.860692	validation_1-rmse:0.972451
# [1800]	validation_0-rmse:0.855263	validation_1-rmse:0.971613
# [1900]	validation_0-rmse:0.850446	validation_1-rmse:0.971224
# [2000]	validation_0-rmse:0.845764	validation_1-rmse:0.970996
# [2100]	validation_0-rmse:0.840953	validation_1-rmse:0.97061
# [2200]	validation_0-rmse:0.836245	validation_1-rmse:0.970465
# [2300]	validation_0-rmse:0.831839	validation_1-rmse:0.970074
# [2400]	validation_0-rmse:0.827475	validation_1-rmse:0.970041
# [2500]	validation_0-rmse:0.82343	validation_1-rmse:0.969643
# Stopping. Best iteration:
# [2489]	validation_0-rmse:0.823924	validation_1-rmse:0.969597
#
# Running k-fold 2 of 5
# [0]	validation_0-rmse:1.86318	validation_1-rmse:1.88108
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53727	validation_1-rmse:1.56051
# [200]	validation_0-rmse:1.31869	validation_1-rmse:1.3494
# [300]	validation_0-rmse:1.1751	validation_1-rmse:1.21382
# [400]	validation_0-rmse:1.08266	validation_1-rmse:1.13021
# [500]	validation_0-rmse:1.02311	validation_1-rmse:1.079
# [600]	validation_0-rmse:0.983794	validation_1-rmse:1.04744
# [700]	validation_0-rmse:0.95704	validation_1-rmse:1.02808
# [800]	validation_0-rmse:0.937952	validation_1-rmse:1.0158
# [900]	validation_0-rmse:0.923434	validation_1-rmse:1.00775
# [1000]	validation_0-rmse:0.911892	validation_1-rmse:1.00228
# [1100]	validation_0-rmse:0.902303	validation_1-rmse:0.998366
# [1200]	validation_0-rmse:0.894096	validation_1-rmse:0.995821
# [1300]	validation_0-rmse:0.886824	validation_1-rmse:0.993974
# [1400]	validation_0-rmse:0.880229	validation_1-rmse:0.992459
# [1500]	validation_0-rmse:0.874073	validation_1-rmse:0.991026
# [1600]	validation_0-rmse:0.868298	validation_1-rmse:0.990008
# [1700]	validation_0-rmse:0.863025	validation_1-rmse:0.989133
# [1800]	validation_0-rmse:0.857843	validation_1-rmse:0.988607
# [1900]	validation_0-rmse:0.853158	validation_1-rmse:0.987979
# [2000]	validation_0-rmse:0.848367	validation_1-rmse:0.987518
# [2100]	validation_0-rmse:0.84376	validation_1-rmse:0.987414
# [2200]	validation_0-rmse:0.839512	validation_1-rmse:0.987101
# Stopping. Best iteration:
# [2178]	validation_0-rmse:0.84043	validation_1-rmse:0.987061
#
# Running k-fold 3 of 5
# [0]	validation_0-rmse:1.85987	validation_1-rmse:1.89399
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53576	validation_1-rmse:1.56791
# [200]	validation_0-rmse:1.31712	validation_1-rmse:1.34979
# [300]	validation_0-rmse:1.17435	validation_1-rmse:1.21023
# [400]	validation_0-rmse:1.08235	validation_1-rmse:1.1226
# [500]	validation_0-rmse:1.02293	validation_1-rmse:1.06892
# [600]	validation_0-rmse:0.983407	validation_1-rmse:1.03593
# [700]	validation_0-rmse:0.956936	validation_1-rmse:1.01599
# [800]	validation_0-rmse:0.937482	validation_1-rmse:1.00304
# [900]	validation_0-rmse:0.922819	validation_1-rmse:0.99483
# [1000]	validation_0-rmse:0.91125	validation_1-rmse:0.989666
# [1100]	validation_0-rmse:0.901513	validation_1-rmse:0.98627
# [1200]	validation_0-rmse:0.893206	validation_1-rmse:0.983709
# [1300]	validation_0-rmse:0.885855	validation_1-rmse:0.982022
# [1400]	validation_0-rmse:0.879246	validation_1-rmse:0.980658
# [1500]	validation_0-rmse:0.873236	validation_1-rmse:0.979762
# [1600]	validation_0-rmse:0.86745	validation_1-rmse:0.979106
# [1700]	validation_0-rmse:0.862186	validation_1-rmse:0.978625
# [1800]	validation_0-rmse:0.857033	validation_1-rmse:0.978369
# [1900]	validation_0-rmse:0.852052	validation_1-rmse:0.978001
# [2000]	validation_0-rmse:0.847274	validation_1-rmse:0.977813
# [2100]	validation_0-rmse:0.842907	validation_1-rmse:0.977724
# [2200]	validation_0-rmse:0.838299	validation_1-rmse:0.977435
# Stopping. Best iteration:
# [2174]	validation_0-rmse:0.839554	validation_1-rmse:0.977376
#
# Running k-fold 4 of 5
# [0]	validation_0-rmse:1.87449	validation_1-rmse:1.83514
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.54376	validation_1-rmse:1.52535
# [200]	validation_0-rmse:1.32159	validation_1-rmse:1.32357
# [300]	validation_0-rmse:1.17438	validation_1-rmse:1.1959
# [400]	validation_0-rmse:1.0795	validation_1-rmse:1.11838
# [500]	validation_0-rmse:1.01848	validation_1-rmse:1.07201
# [600]	validation_0-rmse:0.978312	validation_1-rmse:1.04429
# [700]	validation_0-rmse:0.950808	validation_1-rmse:1.0277
# [800]	validation_0-rmse:0.931281	validation_1-rmse:1.01736
# [900]	validation_0-rmse:0.916648	validation_1-rmse:1.01095
# [1000]	validation_0-rmse:0.90492	validation_1-rmse:1.00628
# [1100]	validation_0-rmse:0.895012	validation_1-rmse:1.00305
# [1200]	validation_0-rmse:0.886849	validation_1-rmse:1.0009
# [1300]	validation_0-rmse:0.879736	validation_1-rmse:0.999354
# [1400]	validation_0-rmse:0.873059	validation_1-rmse:0.998176
# [1500]	validation_0-rmse:0.866879	validation_1-rmse:0.997149
# [1600]	validation_0-rmse:0.861257	validation_1-rmse:0.996359
# [1700]	validation_0-rmse:0.855445	validation_1-rmse:0.995538
# [1800]	validation_0-rmse:0.850225	validation_1-rmse:0.99506
# [1900]	validation_0-rmse:0.845511	validation_1-rmse:0.994515
# [2000]	validation_0-rmse:0.840414	validation_1-rmse:0.994238
# [2100]	validation_0-rmse:0.835839	validation_1-rmse:0.994048
# [2200]	validation_0-rmse:0.831104	validation_1-rmse:0.993748
# [2300]	validation_0-rmse:0.826902	validation_1-rmse:0.993519
# [2400]	validation_0-rmse:0.822459	validation_1-rmse:0.993549
# Stopping. Best iteration:
# [2300]	validation_0-rmse:0.826902	validation_1-rmse:0.993519
#
# Running k-fold 5 of 5
# [0]	validation_0-rmse:1.8688	validation_1-rmse:1.85834
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.5387	validation_1-rmse:1.5453
# [200]	validation_0-rmse:1.31682	validation_1-rmse:1.34134
# [300]	validation_0-rmse:1.17066	validation_1-rmse:1.21252
# [400]	validation_0-rmse:1.07598	validation_1-rmse:1.13372
# [500]	validation_0-rmse:1.01446	validation_1-rmse:1.08652
# [600]	validation_0-rmse:0.974272	validation_1-rmse:1.05906
# [700]	validation_0-rmse:0.946742	validation_1-rmse:1.04271
# [800]	validation_0-rmse:0.927338	validation_1-rmse:1.03273
# [900]	validation_0-rmse:0.912528	validation_1-rmse:1.02677
# [1000]	validation_0-rmse:0.900676	validation_1-rmse:1.02289
# [1100]	validation_0-rmse:0.890753	validation_1-rmse:1.02023
# [1200]	validation_0-rmse:0.881975	validation_1-rmse:1.01815
# [1300]	validation_0-rmse:0.874435	validation_1-rmse:1.01655
# [1400]	validation_0-rmse:0.867518	validation_1-rmse:1.01552
# [1500]	validation_0-rmse:0.861225	validation_1-rmse:1.01456
# [1600]	validation_0-rmse:0.855346	validation_1-rmse:1.01379
# [1700]	validation_0-rmse:0.849927	validation_1-rmse:1.01317
# [1800]	validation_0-rmse:0.84431	validation_1-rmse:1.01281
# [1900]	validation_0-rmse:0.839029	validation_1-rmse:1.01227
# [2000]	validation_0-rmse:0.834257	validation_1-rmse:1.01231
# Stopping. Best iteration:
# [1915]	validation_0-rmse:0.838314	validation_1-rmse:1.01222
#
# ================================================================================
# Training model with random seed: 456
# Running k-fold 1 of 5
# [0]	validation_0-rmse:1.86722	validation_1-rmse:1.86483
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.54033	validation_1-rmse:1.54456
# [200]	validation_0-rmse:1.32002	validation_1-rmse:1.33288
# [300]	validation_0-rmse:1.17592	validation_1-rmse:1.1971
# [400]	validation_0-rmse:1.08212	validation_1-rmse:1.11233
# [500]	validation_0-rmse:1.02186	validation_1-rmse:1.06071
# [600]	validation_0-rmse:0.982165	validation_1-rmse:1.02958
# [700]	validation_0-rmse:0.955499	validation_1-rmse:1.01006
# [800]	validation_0-rmse:0.936308	validation_1-rmse:0.998185
# [900]	validation_0-rmse:0.921666	validation_1-rmse:0.989906
# [1000]	validation_0-rmse:0.909889	validation_1-rmse:0.984562
# [1100]	validation_0-rmse:0.900557	validation_1-rmse:0.9814
# [1200]	validation_0-rmse:0.892176	validation_1-rmse:0.978704
# [1300]	validation_0-rmse:0.884873	validation_1-rmse:0.976663
# [1400]	validation_0-rmse:0.878049	validation_1-rmse:0.975126
# [1500]	validation_0-rmse:0.872053	validation_1-rmse:0.974089
# [1600]	validation_0-rmse:0.866399	validation_1-rmse:0.973321
# [1700]	validation_0-rmse:0.860965	validation_1-rmse:0.972474
# [1800]	validation_0-rmse:0.856054	validation_1-rmse:0.9718
# [1900]	validation_0-rmse:0.851202	validation_1-rmse:0.97117
# [2000]	validation_0-rmse:0.846314	validation_1-rmse:0.970989
# [2100]	validation_0-rmse:0.841799	validation_1-rmse:0.970247
# [2200]	validation_0-rmse:0.837146	validation_1-rmse:0.969878
# [2300]	validation_0-rmse:0.832622	validation_1-rmse:0.969889
# [2400]	validation_0-rmse:0.828254	validation_1-rmse:0.969718
# [2500]	validation_0-rmse:0.823851	validation_1-rmse:0.969564
# [2600]	validation_0-rmse:0.820019	validation_1-rmse:0.969153
# [2700]	validation_0-rmse:0.816113	validation_1-rmse:0.969114
# [2800]	validation_0-rmse:0.812088	validation_1-rmse:0.968819
# [2900]	validation_0-rmse:0.808144	validation_1-rmse:0.968597
# [3000]	validation_0-rmse:0.804234	validation_1-rmse:0.968295
# [3100]	validation_0-rmse:0.800456	validation_1-rmse:0.968358
# Stopping. Best iteration:
# [3046]	validation_0-rmse:0.802434	validation_1-rmse:0.968187
#
# Running k-fold 2 of 5
# [0]	validation_0-rmse:1.86316	validation_1-rmse:1.88111
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53773	validation_1-rmse:1.5611
# [200]	validation_0-rmse:1.31835	validation_1-rmse:1.34855
# [300]	validation_0-rmse:1.17525	validation_1-rmse:1.21381
# [400]	validation_0-rmse:1.08299	validation_1-rmse:1.12965
# [500]	validation_0-rmse:1.02331	validation_1-rmse:1.07802
# [600]	validation_0-rmse:0.984154	validation_1-rmse:1.04667
# [700]	validation_0-rmse:0.957463	validation_1-rmse:1.02756
# [800]	validation_0-rmse:0.93815	validation_1-rmse:1.01502
# [900]	validation_0-rmse:0.923726	validation_1-rmse:1.00694
# [1000]	validation_0-rmse:0.912086	validation_1-rmse:1.00144
# [1100]	validation_0-rmse:0.902661	validation_1-rmse:0.997884
# [1200]	validation_0-rmse:0.894542	validation_1-rmse:0.995218
# [1300]	validation_0-rmse:0.887031	validation_1-rmse:0.993007
# [1400]	validation_0-rmse:0.88033	validation_1-rmse:0.991533
# [1500]	validation_0-rmse:0.874465	validation_1-rmse:0.990441
# [1600]	validation_0-rmse:0.868786	validation_1-rmse:0.989392
# [1700]	validation_0-rmse:0.863606	validation_1-rmse:0.98846
# [1800]	validation_0-rmse:0.858504	validation_1-rmse:0.987764
# [1900]	validation_0-rmse:0.853599	validation_1-rmse:0.987225
# [2000]	validation_0-rmse:0.848681	validation_1-rmse:0.98671
# [2100]	validation_0-rmse:0.844368	validation_1-rmse:0.986261
# [2200]	validation_0-rmse:0.83993	validation_1-rmse:0.985941
# [2300]	validation_0-rmse:0.835659	validation_1-rmse:0.985779
# [2400]	validation_0-rmse:0.83162	validation_1-rmse:0.985425
# [2500]	validation_0-rmse:0.827562	validation_1-rmse:0.985298
# [2600]	validation_0-rmse:0.823643	validation_1-rmse:0.985051
# [2700]	validation_0-rmse:0.819645	validation_1-rmse:0.985097
# Stopping. Best iteration:
# [2603]	validation_0-rmse:0.823523	validation_1-rmse:0.985045
#
# Running k-fold 3 of 5
# [0]	validation_0-rmse:1.85987	validation_1-rmse:1.89403
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53587	validation_1-rmse:1.56814
# [200]	validation_0-rmse:1.31759	validation_1-rmse:1.35073
# [300]	validation_0-rmse:1.17485	validation_1-rmse:1.21125
# [400]	validation_0-rmse:1.08266	validation_1-rmse:1.1239
# [500]	validation_0-rmse:1.02328	validation_1-rmse:1.07049
# [600]	validation_0-rmse:0.98369	validation_1-rmse:1.03764
# [700]	validation_0-rmse:0.95677	validation_1-rmse:1.0171
# [800]	validation_0-rmse:0.937413	validation_1-rmse:1.00426
# [900]	validation_0-rmse:0.922719	validation_1-rmse:0.996213
# [1000]	validation_0-rmse:0.911119	validation_1-rmse:0.991036
# [1100]	validation_0-rmse:0.901433	validation_1-rmse:0.987163
# [1200]	validation_0-rmse:0.89303	validation_1-rmse:0.984826
# [1300]	validation_0-rmse:0.885688	validation_1-rmse:0.98292
# [1400]	validation_0-rmse:0.879161	validation_1-rmse:0.981633
# [1500]	validation_0-rmse:0.872706	validation_1-rmse:0.980602
# [1600]	validation_0-rmse:0.866939	validation_1-rmse:0.979839
# [1700]	validation_0-rmse:0.861517	validation_1-rmse:0.979302
# [1800]	validation_0-rmse:0.856524	validation_1-rmse:0.978768
# [1900]	validation_0-rmse:0.851551	validation_1-rmse:0.978523
# [2000]	validation_0-rmse:0.846653	validation_1-rmse:0.978233
# [2100]	validation_0-rmse:0.841999	validation_1-rmse:0.97812
# Stopping. Best iteration:
# [2094]	validation_0-rmse:0.842224	validation_1-rmse:0.978091
#
# Running k-fold 4 of 5
# [0]	validation_0-rmse:1.87456	validation_1-rmse:1.83524
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.54318	validation_1-rmse:1.52459
# [200]	validation_0-rmse:1.32068	validation_1-rmse:1.32283
# [300]	validation_0-rmse:1.17391	validation_1-rmse:1.19558
# [400]	validation_0-rmse:1.07939	validation_1-rmse:1.11795
# [500]	validation_0-rmse:1.01842	validation_1-rmse:1.07154
# [600]	validation_0-rmse:0.978409	validation_1-rmse:1.04422
# [700]	validation_0-rmse:0.951296	validation_1-rmse:1.02766
# [800]	validation_0-rmse:0.931665	validation_1-rmse:1.01732
# [900]	validation_0-rmse:0.916798	validation_1-rmse:1.01067
# [1000]	validation_0-rmse:0.905064	validation_1-rmse:1.00624
# [1100]	validation_0-rmse:0.89515	validation_1-rmse:1.00328
# [1200]	validation_0-rmse:0.886525	validation_1-rmse:1.00076
# [1300]	validation_0-rmse:0.879211	validation_1-rmse:0.999228
# [1400]	validation_0-rmse:0.872431	validation_1-rmse:0.997996
# [1500]	validation_0-rmse:0.866284	validation_1-rmse:0.996891
# [1600]	validation_0-rmse:0.860377	validation_1-rmse:0.996053
# [1700]	validation_0-rmse:0.854955	validation_1-rmse:0.995419
# [1800]	validation_0-rmse:0.849975	validation_1-rmse:0.994796
# [1900]	validation_0-rmse:0.844831	validation_1-rmse:0.994379
# [2000]	validation_0-rmse:0.840072	validation_1-rmse:0.994109
# [2100]	validation_0-rmse:0.835304	validation_1-rmse:0.993533
# [2200]	validation_0-rmse:0.83098	validation_1-rmse:0.99316
# [2300]	validation_0-rmse:0.826652	validation_1-rmse:0.992864
# [2400]	validation_0-rmse:0.82232	validation_1-rmse:0.992755
# [2500]	validation_0-rmse:0.818013	validation_1-rmse:0.992466
# [2600]	validation_0-rmse:0.813778	validation_1-rmse:0.992379
# [2700]	validation_0-rmse:0.809795	validation_1-rmse:0.99215
# [2800]	validation_0-rmse:0.805718	validation_1-rmse:0.991942
# [2900]	validation_0-rmse:0.801746	validation_1-rmse:0.991931
# [3000]	validation_0-rmse:0.798084	validation_1-rmse:0.9919
# [3100]	validation_0-rmse:0.794145	validation_1-rmse:0.991813
# Stopping. Best iteration:
# [3093]	validation_0-rmse:0.794391	validation_1-rmse:0.991777
#
# Running k-fold 5 of 5
# [0]	validation_0-rmse:1.86879	validation_1-rmse:1.85831
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53849	validation_1-rmse:1.54515
# [200]	validation_0-rmse:1.31572	validation_1-rmse:1.34014
# [300]	validation_0-rmse:1.16992	validation_1-rmse:1.21173
# [400]	validation_0-rmse:1.07574	validation_1-rmse:1.13407
# [500]	validation_0-rmse:1.01465	validation_1-rmse:1.08724
# [600]	validation_0-rmse:0.974364	validation_1-rmse:1.05987
# [700]	validation_0-rmse:0.946638	validation_1-rmse:1.04342
# [800]	validation_0-rmse:0.927016	validation_1-rmse:1.03343
# [900]	validation_0-rmse:0.912057	validation_1-rmse:1.02692
# [1000]	validation_0-rmse:0.900295	validation_1-rmse:1.02294
# [1100]	validation_0-rmse:0.890188	validation_1-rmse:1.02016
# [1200]	validation_0-rmse:0.881579	validation_1-rmse:1.0183
# [1300]	validation_0-rmse:0.874104	validation_1-rmse:1.01679
# [1400]	validation_0-rmse:0.867353	validation_1-rmse:1.0158
# [1500]	validation_0-rmse:0.860933	validation_1-rmse:1.01479
# [1600]	validation_0-rmse:0.854918	validation_1-rmse:1.0142
# [1700]	validation_0-rmse:0.849478	validation_1-rmse:1.01364
# [1800]	validation_0-rmse:0.843735	validation_1-rmse:1.01306
# [1900]	validation_0-rmse:0.83891	validation_1-rmse:1.01273
# [2000]	validation_0-rmse:0.834013	validation_1-rmse:1.01232
# [2100]	validation_0-rmse:0.82944	validation_1-rmse:1.01207
# [2200]	validation_0-rmse:0.824953	validation_1-rmse:1.01193
# [2300]	validation_0-rmse:0.820631	validation_1-rmse:1.01169
# [2400]	validation_0-rmse:0.816292	validation_1-rmse:1.01163
# [2500]	validation_0-rmse:0.812155	validation_1-rmse:1.01143
# [2600]	validation_0-rmse:0.808042	validation_1-rmse:1.01138
# Stopping. Best iteration:
# [2534]	validation_0-rmse:0.810654	validation_1-rmse:1.01131
#
# ================================================================================
# Training model with random seed: 923
# Running k-fold 1 of 5
# [0]	validation_0-rmse:1.86721	validation_1-rmse:1.86478
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.54009	validation_1-rmse:1.54461
# [200]	validation_0-rmse:1.3196	validation_1-rmse:1.3327
# [300]	validation_0-rmse:1.17535	validation_1-rmse:1.19765
# [400]	validation_0-rmse:1.08205	validation_1-rmse:1.11343
# [500]	validation_0-rmse:1.02164	validation_1-rmse:1.06205
# [600]	validation_0-rmse:0.982161	validation_1-rmse:1.03112
# [700]	validation_0-rmse:0.955265	validation_1-rmse:1.01225
# [800]	validation_0-rmse:0.936047	validation_1-rmse:1.00012
# [900]	validation_0-rmse:0.921756	validation_1-rmse:0.992267
# [1000]	validation_0-rmse:0.910267	validation_1-rmse:0.987333
# [1100]	validation_0-rmse:0.900494	validation_1-rmse:0.983595
# [1200]	validation_0-rmse:0.892347	validation_1-rmse:0.981158
# [1300]	validation_0-rmse:0.88508	validation_1-rmse:0.978817
# [1400]	validation_0-rmse:0.878369	validation_1-rmse:0.977137
# [1500]	validation_0-rmse:0.872038	validation_1-rmse:0.975869
# [1600]	validation_0-rmse:0.866273	validation_1-rmse:0.974752
# [1700]	validation_0-rmse:0.860739	validation_1-rmse:0.973395
# [1800]	validation_0-rmse:0.855521	validation_1-rmse:0.97248
# [1900]	validation_0-rmse:0.850637	validation_1-rmse:0.97157
# [2000]	validation_0-rmse:0.845852	validation_1-rmse:0.971011
# [2100]	validation_0-rmse:0.841042	validation_1-rmse:0.970691
# [2200]	validation_0-rmse:0.836517	validation_1-rmse:0.970605
# [2300]	validation_0-rmse:0.832181	validation_1-rmse:0.97033
# [2400]	validation_0-rmse:0.827953	validation_1-rmse:0.969833
# [2500]	validation_0-rmse:0.823792	validation_1-rmse:0.969419
# [2600]	validation_0-rmse:0.820009	validation_1-rmse:0.969102
# [2700]	validation_0-rmse:0.816074	validation_1-rmse:0.968867
# [2800]	validation_0-rmse:0.81199	validation_1-rmse:0.968749
# [2900]	validation_0-rmse:0.808302	validation_1-rmse:0.968737
# [3000]	validation_0-rmse:0.804492	validation_1-rmse:0.968724
# Stopping. Best iteration:
# [2940]	validation_0-rmse:0.806774	validation_1-rmse:0.968648
#
# Running k-fold 2 of 5
# [0]	validation_0-rmse:1.86314	validation_1-rmse:1.88108
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.5372	validation_1-rmse:1.56072
# [200]	validation_0-rmse:1.3183	validation_1-rmse:1.3487
# [300]	validation_0-rmse:1.17498	validation_1-rmse:1.21383
# [400]	validation_0-rmse:1.08243	validation_1-rmse:1.12935
# [500]	validation_0-rmse:1.02278	validation_1-rmse:1.07759
# [600]	validation_0-rmse:0.983367	validation_1-rmse:1.04593
# [700]	validation_0-rmse:0.956539	validation_1-rmse:1.02633
# [800]	validation_0-rmse:0.937521	validation_1-rmse:1.01431
# [900]	validation_0-rmse:0.922982	validation_1-rmse:1.00621
# [1000]	validation_0-rmse:0.911387	validation_1-rmse:1.0006
# [1100]	validation_0-rmse:0.90162	validation_1-rmse:0.996847
# [1200]	validation_0-rmse:0.893318	validation_1-rmse:0.994017
# [1300]	validation_0-rmse:0.885939	validation_1-rmse:0.991975
# [1400]	validation_0-rmse:0.879507	validation_1-rmse:0.990346
# [1500]	validation_0-rmse:0.873538	validation_1-rmse:0.989052
# [1600]	validation_0-rmse:0.868019	validation_1-rmse:0.988287
# [1700]	validation_0-rmse:0.863052	validation_1-rmse:0.98759
# [1800]	validation_0-rmse:0.858145	validation_1-rmse:0.986735
# [1900]	validation_0-rmse:0.853258	validation_1-rmse:0.986372
# [2000]	validation_0-rmse:0.848675	validation_1-rmse:0.985773
# [2100]	validation_0-rmse:0.844095	validation_1-rmse:0.985688
# [2200]	validation_0-rmse:0.83975	validation_1-rmse:0.985335
# [2300]	validation_0-rmse:0.835385	validation_1-rmse:0.985217
# [2400]	validation_0-rmse:0.831107	validation_1-rmse:0.985022
# [2500]	validation_0-rmse:0.826763	validation_1-rmse:0.984837
# [2600]	validation_0-rmse:0.822568	validation_1-rmse:0.984615
# [2700]	validation_0-rmse:0.818508	validation_1-rmse:0.984429
# Stopping. Best iteration:
# [2665]	validation_0-rmse:0.819864	validation_1-rmse:0.984394
#
# Running k-fold 3 of 5
# [0]	validation_0-rmse:1.85982	validation_1-rmse:1.89397
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.5356	validation_1-rmse:1.56815
# [200]	validation_0-rmse:1.31798	validation_1-rmse:1.35154
# [300]	validation_0-rmse:1.17453	validation_1-rmse:1.21165
# [400]	validation_0-rmse:1.08269	validation_1-rmse:1.12475
# [500]	validation_0-rmse:1.0231	validation_1-rmse:1.07059
# [600]	validation_0-rmse:0.983777	validation_1-rmse:1.03734
# [700]	validation_0-rmse:0.956783	validation_1-rmse:1.01666
# [800]	validation_0-rmse:0.937518	validation_1-rmse:1.0039
# [900]	validation_0-rmse:0.922953	validation_1-rmse:0.995645
# [1000]	validation_0-rmse:0.911327	validation_1-rmse:0.99037
# [1100]	validation_0-rmse:0.901355	validation_1-rmse:0.986747
# [1200]	validation_0-rmse:0.893271	validation_1-rmse:0.984449
# [1300]	validation_0-rmse:0.886119	validation_1-rmse:0.98285
# [1400]	validation_0-rmse:0.879181	validation_1-rmse:0.98145
# [1500]	validation_0-rmse:0.873083	validation_1-rmse:0.980405
# [1600]	validation_0-rmse:0.867079	validation_1-rmse:0.979536
# [1700]	validation_0-rmse:0.861658	validation_1-rmse:0.979025
# [1800]	validation_0-rmse:0.8564	validation_1-rmse:0.978632
# [1900]	validation_0-rmse:0.851767	validation_1-rmse:0.978208
# [2000]	validation_0-rmse:0.846917	validation_1-rmse:0.977889
# [2100]	validation_0-rmse:0.842615	validation_1-rmse:0.977678
# [2200]	validation_0-rmse:0.838117	validation_1-rmse:0.977463
# [2300]	validation_0-rmse:0.833829	validation_1-rmse:0.977541
# Stopping. Best iteration:
# [2214]	validation_0-rmse:0.837582	validation_1-rmse:0.977401
#
# Running k-fold 4 of 5
# [0]	validation_0-rmse:1.87449	validation_1-rmse:1.83516
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.54365	validation_1-rmse:1.52514
# [200]	validation_0-rmse:1.32129	validation_1-rmse:1.32341
# [300]	validation_0-rmse:1.17462	validation_1-rmse:1.19635
# [400]	validation_0-rmse:1.07971	validation_1-rmse:1.11888
# [500]	validation_0-rmse:1.01872	validation_1-rmse:1.07252
# [600]	validation_0-rmse:0.978709	validation_1-rmse:1.0448
# [700]	validation_0-rmse:0.951242	validation_1-rmse:1.02804
# [800]	validation_0-rmse:0.931997	validation_1-rmse:1.01781
# [900]	validation_0-rmse:0.916902	validation_1-rmse:1.01101
# [1000]	validation_0-rmse:0.905214	validation_1-rmse:1.00643
# [1100]	validation_0-rmse:0.895346	validation_1-rmse:1.00335
# [1200]	validation_0-rmse:0.887053	validation_1-rmse:1.00112
# [1300]	validation_0-rmse:0.879876	validation_1-rmse:0.999408
# [1400]	validation_0-rmse:0.873319	validation_1-rmse:0.998266
# [1500]	validation_0-rmse:0.866808	validation_1-rmse:0.996949
# [1600]	validation_0-rmse:0.860857	validation_1-rmse:0.996214
# [1700]	validation_0-rmse:0.855303	validation_1-rmse:0.995461
# [1800]	validation_0-rmse:0.850354	validation_1-rmse:0.994979
# [1900]	validation_0-rmse:0.845056	validation_1-rmse:0.994567
# [2000]	validation_0-rmse:0.84042	validation_1-rmse:0.994147
# [2100]	validation_0-rmse:0.835503	validation_1-rmse:0.993938
# [2200]	validation_0-rmse:0.830906	validation_1-rmse:0.993617
# [2300]	validation_0-rmse:0.82629	validation_1-rmse:0.993391
# [2400]	validation_0-rmse:0.821789	validation_1-rmse:0.993034
# [2500]	validation_0-rmse:0.81748	validation_1-rmse:0.993049
# [2600]	validation_0-rmse:0.813238	validation_1-rmse:0.992643
# [2700]	validation_0-rmse:0.809257	validation_1-rmse:0.992477
# [2800]	validation_0-rmse:0.805526	validation_1-rmse:0.992324
# [2900]	validation_0-rmse:0.801661	validation_1-rmse:0.992271
# [3000]	validation_0-rmse:0.797917	validation_1-rmse:0.992084
# [3100]	validation_0-rmse:0.794055	validation_1-rmse:0.992063
# Stopping. Best iteration:
# [3072]	validation_0-rmse:0.795153	validation_1-rmse:0.992
#
# Running k-fold 5 of 5
# [0]	validation_0-rmse:1.86876	validation_1-rmse:1.85831
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [100]	validation_0-rmse:1.53895	validation_1-rmse:1.5453
# [200]	validation_0-rmse:1.31619	validation_1-rmse:1.34055
# [300]	validation_0-rmse:1.16966	validation_1-rmse:1.21151
# [400]	validation_0-rmse:1.07525	validation_1-rmse:1.1329
# [500]	validation_0-rmse:1.01427	validation_1-rmse:1.08617
# [600]	validation_0-rmse:0.974064	validation_1-rmse:1.05826
# [700]	validation_0-rmse:0.946658	validation_1-rmse:1.04169
# [800]	validation_0-rmse:0.927066	validation_1-rmse:1.03156
# [900]	validation_0-rmse:0.912136	validation_1-rmse:1.02535
# [1000]	validation_0-rmse:0.900416	validation_1-rmse:1.0215
# [1100]	validation_0-rmse:0.890519	validation_1-rmse:1.01879
# [1200]	validation_0-rmse:0.882257	validation_1-rmse:1.01689
# [1300]	validation_0-rmse:0.874786	validation_1-rmse:1.01544
# [1400]	validation_0-rmse:0.867664	validation_1-rmse:1.01424
# [1500]	validation_0-rmse:0.861392	validation_1-rmse:1.01341
# [1600]	validation_0-rmse:0.85545	validation_1-rmse:1.01267
# [1700]	validation_0-rmse:0.850007	validation_1-rmse:1.01216
# [1800]	validation_0-rmse:0.844825	validation_1-rmse:1.01168

# %%
rounders = [Rounder(method='dist'), Rounder(method='optimal')]
labels = []
for rounder in rounders:
    for i, result in enumerate(ensemble, 1):
        rounder.fit(X_trn['accuracy_group'], result.oof)
        for j, model in enumerate(result.models, 1):
            U.log(f'Rounder: {rounder.method}, ensemble #{i}, model #{j}')
            model_pred = model.predict(X_tst[features])
            model_labels = rounder.predict(model_pred)
            labels.append(model_labels)

# %%
bundle.save({
    'rounders': rounders, 
    'ensemble': [result.models for result in ensemble]
}, key='xgboost')

# %%
algo = 'lightgbm'
version = '024'

if U.on_kaggle():
    U.log('Inference on Kaggle.')
    features = bundle.features()
    bounds = bundle.bounds()
    predicted = inference(X_tst, features, bounds=bounds, model=algo, version=version)
    U.log('Saving predictions on disk.')
    filename = submit(predicted)
    submit_df = pd.read_csv(filename)
    U.log('First 20 submission rows:')
    display(submit_df.head(20))
    
else:
    U.log(f'Training model: {algo}')
    cappa = make_cappa_metric(X_trn['accuracy_group'])
    trainer = EnsembleTrainer(algo=algo, cv_metrics={'cappa': cappa})
    fold = GroupKFold(n_splits=5)
    config = get_default_config(algo)
    U.set_nested(config, 'model_params.feature_fraction', 0.4)
    U.set_nested(config, 'model_params.bagging_fraction', 0.5)
    U.set_nested(config, 'model_params.bagging_freq', 1)
    U.set_nested(config, 'model_params.learning_rate', 0.003)
    result = trainer.train(X_trn, features=features, fold=fold, config=config)
    U.log('Saving the trained models')
    bundle.save(result.models, f'models_{algo}_{version}')
    U.log('Saving the optimal rounding bounds')
    bounds = optimize_rounding_bounds(result.oof, X_trn['accuracy_group'].values)
    U.log(f'Optimal bounds: {bounds}')
    bundle.save(bounds, 'bounds')
    U.log(f'Final features number: {len(features)}')
    bundle.save(features, 'features')

# %%
if not U.on_kaggle():
    import os
    features = bundle.features()
    bounds = bundle.bounds()
    filename = submit(inference(X_tst, features, bounds, model=algo, version=version))
    assert os.path.exists(filename)
    assert pd.read_csv(filename).shape[0] == 1000
    bundle.package(folder='/home/ck/data/bowl2019/external/')

# %%
# %matplotlib inline

# %%
pd.read_csv('submission.csv')['accuracy_group'].value_counts().reset_index().sort_values(by='index').set_index('index').plot.bar()

# %%
X_trn['accuracy_group'].value_counts().reset_index().sort_values(by='index').set_index('index').plot.bar()

# %% [markdown]
# ## Stack Many Models

# %%
bundle.package(folder='/home/ck/data/bowl2019/external/')
# Out:
# Packaging training results into dataset.
# /tmp/bowl2019/meta.joblib --> /home/ck/data/bowl2019/external/meta.joblib
# /tmp/bowl2019/lightgbm.joblib --> /home/ck/data/bowl2019/external/lightgbm.joblib
# /tmp/bowl2019/target_encoders.joblib --> /home/ck/data/bowl2019/external/target_encoders.joblib
# /tmp/bowl2019/bounds.joblib --> /home/ck/data/bowl2019/external/bounds.joblib
# /tmp/bowl2019/xgboost.joblib --> /home/ck/data/bowl2019/external/xgboost.joblib
# /tmp/bowl2019/features.joblib --> /home/ck/data/bowl2019/external/features.joblib
# /tmp/bowl2019/encoders.joblib --> /home/ck/data/bowl2019/external/encoders.joblib
# /tmp/bowl2019/models_lightgbm_24.joblib --> /home/ck/data/bowl2019/external/models_lightgbm_24.joblib
# /tmp/bowl2019/models_lightgbm_023.joblib --> /home/ck/data/bowl2019/external/models_lightgbm_023.joblib
# Packaging helper scripts into dataset.
# ../selection.py --> /home/ck/data/bowl2019/external/selection.py
# ../encode.py --> /home/ck/data/bowl2019/external/encode.py
# ../features.py --> /home/ck/data/bowl2019/external/features.py
# ../training.py --> /home/ck/data/bowl2019/external/training.py
# ../feedback.py --> /home/ck/data/bowl2019/external/feedback.py
# ../style.py --> /home/ck/data/bowl2019/external/style.py
# ../duration.py --> /home/ck/data/bowl2019/external/duration.py
# ../basedir.py --> /home/ck/data/bowl2019/external/basedir.py
# ../dataset.py --> /home/ck/data/bowl2019/external/dataset.py
# ../models.py --> /home/ck/data/bowl2019/external/models.py
# ../extract_features.py --> /home/ck/data/bowl2019/external/extract_features.py
# ../plots.py --> /home/ck/data/bowl2019/external/plots.py
# ../rounding.py --> /home/ck/data/bowl2019/external/rounding.py
# ../normalize.py --> /home/ck/data/bowl2019/external/normalize.py
# ../meta.py --> /home/ck/data/bowl2019/external/meta.py
# ../bundle.py --> /home/ck/data/bowl2019/external/bundle.py
# ../metric.py --> /home/ck/data/bowl2019/external/metric.py
# ../utils.py --> /home/ck/data/bowl2019/external/utils.py
# '/home/ck/data/bowl2019/external/'
